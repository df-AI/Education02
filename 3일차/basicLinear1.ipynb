# %%
import tensorflow as tf
tf.reset_default_graph()

# %%
X = [1,2,3]
Y = [1,2,3]

x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float32)


w = tf.Variable(tf.random_normal([1]), name ='weight')
b = tf.Variable(tf.random_normal([1]), name ='bias')

hypothesis = w*x +b
#hypothesis = tf.matmul(x,w) + b

cost = tf.reduce_mean(tf.square(hypothesis - y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()

sess.run(tf.global_variables_initializer())

for step in range(2000):
#  cost_val, w_val, b_val, _ = sess.run([cost, w, b, train], feed_dict = {x:[1,2,3,4,5],
#                               y:[2,3,4,5,6]})
  cost_val, w_val, b_val, _ = sess.run([cost, w, b, train], feed_dict = {x:X, y:Y})

  if step %20 ==0:
    print(step, cost_val, w_val, b_val)

#x =4,5일때 예측값
print(sess.run(hypothesis, feed_dict = {x:[4,5]}))
    
sess.close()
# Out:
# 0 4.1930594 [-0.1674291] [0.77278286]
# 20 0.18857276 [0.4821504] [0.99808085]
# 40 0.13844667 [0.56311566] [0.9760858]
# 60 0.12544192 [0.58903974] [0.93258536]
# 80 0.11392564 [0.6088668] [0.8889831]
# 100 0.10346913 [0.6272975] [0.8472257]
# 120 0.09397229 [0.64481777] [0.80741125]
# 140 0.08534718 [0.66151047] [0.76946616]
# 160 0.07751364 [0.6774183] [0.7333041]
# 180 0.07039914 [0.6925784] [0.69884163]
# 200 0.06393769 [0.70702606] [0.66599876]
# 220 0.058069196 [0.7207948] [0.63469917]
# 240 0.0527394 [0.7339163] [0.6048707]
# 260 0.04789877 [0.74642134] [0.576444]
# 280 0.043502416 [0.7583386] [0.54935324]
# 300 0.039509565 [0.7696958] [0.5235356]
# 320 0.03588326 [0.78051925] [0.49893147]
# 340 0.032589715 [0.79083407] [0.47548345]
# 360 0.029598499 [0.80066407] [0.4531374]
# 380 0.026881838 [0.81003207] [0.43184167]
# 400 0.024414534 [0.8189599] [0.4115467]
# 420 0.022173675 [0.8274682] [0.39220554]
# 440 0.020138472 [0.8355765] [0.37377325]
# 460 0.018290063 [0.84330386] [0.35620722]
# 480 0.01661133 [0.85066795] [0.33946675]
# 500 0.015086669 [0.857686] [0.3235131]
# 520 0.013701968 [0.8643742] [0.3083092]
# 540 0.012444332 [0.8707482] [0.29381976]
# 560 0.011302144 [0.87682253] [0.2800113]
# 580 0.0102648 [0.8826114] [0.26685184]
# 600 0.009322667 [0.88812834] [0.25431082]
# 620 0.008466989 [0.89338577] [0.24235913]
# 640 0.007689851 [0.8983963] [0.23096913]
# 660 0.00698404 [0.9031713] [0.22011444]
# 680 0.0063430234 [0.90772194] [0.20976986]
# 700 0.005760825 [0.9120586] [0.19991143]
# 720 0.005232085 [0.9161915] [0.19051634]
# 740 0.00475186 [0.9201303] [0.18156275]
# 760 0.0043157157 [0.9238838] [0.17302999]
# 780 0.0039195945 [0.927461] [0.16489822]
# 800 0.0035598446 [0.9308701] [0.15714857]
# 820 0.0032331047 [0.9341189] [0.14976317]
# 840 0.0029363555 [0.9372151] [0.14272483]
# 860 0.0026668448 [0.94016576] [0.1360173]
